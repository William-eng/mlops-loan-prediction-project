# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
train = pd.read_csv('../data/raw/train.csv')

# Basic info
print("Dataset shape:", train.shape)
print("\nFirst few rows:")
print(train.head())

print("\nData types:")
print(train.dtypes)

print("\nMissing values:")
print(train.isnull().sum())

print("\nTarget distribution:")
print(train['Loan_Status'].value_counts())

# Visualizations
plt.figure(figsize=(12, 4))

plt.subplot(131)
train['Loan_Status'].value_counts().plot(kind='bar')
plt.title('Loan Status Distribution')

plt.subplot(132)
train['Gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')

plt.subplot(133)
train['Property_Area'].value_counts().plot(kind='bar')
plt.title('Property Area Distribution')

plt.tight_layout()
plt.show()

# Income analysis
plt.figure(figsize=(10, 4))
plt.subplot(121)
train.boxplot(column='ApplicantIncome', by='Loan_Status')
plt.title('Applicant Income by Loan Status')

plt.subplot(122)
train.boxplot(column='LoanAmount', by='Loan_Status')
plt.title('Loan Amount by Loan Status')

plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Dataset shape: (491, 13)
#
# First few rows:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP000351  Female     Yes          1  Not Graduate            No
# 1  LP000378    Male      No          2      Graduate            No
# 2  LP000164  Female      No          1      Graduate           Yes
# 3  LP000610  Female     Yes         3+  Not Graduate            No
# 4  LP000133    Male     Yes          1  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            13066               4093       322.0               360
# 1            11930               3500       277.0               120
# 2            11155               4600        40.0               180
# 3             6075               4810        48.0               300
# 4             9385               3516         NaN               300
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           N
# 1             1.0         Urban           N
# 2             1.0         Rural           Y
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y
#
# Data types:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term       int64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object
#
# Missing values:
# Loan_ID               0
# Gender               17
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           15
# Loan_Amount_Term      0
# Credit_History       15
# Property_Area         0
# Loan_Status           0
# dtype: int64
#
# Target distribution:
# Loan_Status
# N    334
# Y    157
# Name: count, dtype: int64
